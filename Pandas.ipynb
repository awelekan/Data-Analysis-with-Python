# %%
#Panel Data System (Pandas)
#The Python Library must be installed

import pandas

dir(pandas)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
m = {
    "cars": ['ford', 'mazda','toyota'],
    'model':[2023, 2020, 2021]
}

nakel= pandas.DataFrame(m)
print(m)
# Out:
# {'cars': ['ford', 'mazda', 'toyota'], 'model': [2023, 2020, 2021]}

# %%
#Alias as

import pandas as pd

# %%
m = {
    "cars": ['ford', 'mazda','toyota'],
    'model':[2023, 2020, 2021]
}

nakel= pd.DataFrame(m)
print(nakel)
# Out:
#      cars  model
# 0    ford   2023
# 1   mazda   2020
# 2  toyota   2021

# %%
import pandas as pd

cars = ['ford', 'mazda','toyota']
halimah= pd.Series(cars)
print(halimah)
# Out:
# 0      ford
# 1     mazda
# 2    toyota
# dtype: object

# %%
#DataFrame
import pandas as pd

m = {
    "cars": ['ford', 'mazda','toyota'],
    'model':[2023, 2020, 2021],
    'num': [1,3,5]
}

df = pd.DataFrame(m)
print(df)
# Out:
#      cars  model  num
# 0    ford   2023    1
# 1   mazda   2020    3
# 2  toyota   2021    5

# %%
#Read from file
import pandas as pd

oye= pd.read_csv(r'C:\Users\TheMs\Documents\Data Analysis\Attrition dataseeet.csv')

oye
# Out:
#      Attrition    Business Travel CF_age band Department Education Field  \
# 0          Yes      Travel_Rarely     35 - 44      Sales   Life Sciences
# 1           No  Travel_Frequently     45 - 54        R&D   Life Sciences
# 2          Yes      Travel_Rarely     35 - 44        R&D           Other
# 3          Yes  Travel_Frequently     25 - 34        R&D   Life Sciences
# 4          Yes      Travel_Rarely     25 - 34        R&D         Medical
# ...        ...                ...         ...        ...             ...
# 2920       Yes  Travel_Frequently     35 - 44      Sales           Other
# 2921       Yes      Travel_Rarely       18-25        R&D   Life Sciences
# 2922       Yes      Travel_Rarely       18-25      Sales   Life Sciences
# 2923       Yes      Travel_Rarely    Under 26      Sales   Life Sciences
# 2924       Yes      Travel_Rarely    Under 27      Sales   Life Sciences
#
#           emp no  Gender               Job Role Marital Status Over Time  ...  \
# ...

# %%
pd.options.display.max_rows =2925

df = pd.read_csv(r'C:\Users\TheMs\Documents\Data Analysis\Attrition dataseeet.csv')
df
# Out:
#      Attrition    Business Travel CF_age band Department   Education Field  \
# 0          Yes      Travel_Rarely     35 - 44      Sales     Life Sciences
# 1           No  Travel_Frequently     45 - 54        R&D     Life Sciences
# 2          Yes      Travel_Rarely     35 - 44        R&D             Other
# 3          Yes  Travel_Frequently     25 - 34        R&D     Life Sciences
# 4          Yes      Travel_Rarely     25 - 34        R&D           Medical
# 5          Yes  Travel_Frequently     25 - 34        R&D     Life Sciences
# 6          Yes      Travel_Rarely     55 plus        R&D           Medical
# 7          Yes      Travel_Rarely     25 - 34        R&D     Life Sciences
# 8          Yes  Travel_Frequently     35 - 44        R&D     Life Sciences
# 9          Yes      Travel_Rarely     35 - 44        R&D           Medical
# 10         Yes      Travel_Rarely     35 - 44        R&D           Medical
# ...
